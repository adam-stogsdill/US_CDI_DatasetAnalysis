# %%
# Perform imports
import pandas as pd
import matplotlib.pyplot as plt
import plotly as p
import plotly.express as px
import plotly.graph_objects as go
import os

# %%
# Load in the data
data = pd.read_csv("./Asthma.csv").drop(columns=["Unnamed: 0"])
data.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource   Topic  \
# 0       2014     2014           AR              Arkansas  SEDD; SID  Asthma
# 1       2018     2018           CO              Colorado  SEDD; SID  Asthma
# 2       2018     2018           DC  District of Columbia  SEDD; SID  Asthma
# 3       2017     2017           GA               Georgia  SEDD; SID  Asthma
# 4       2010     2010           MI              Michigan  SEDD; SID  Asthma
#
#                       Question DataValueUnit DataValueType  DataValue  ...  \
# 0  Hospitalizations for asthma           NaN        Number      916.0  ...
# 1  Hospitalizations for asthma           NaN        Number     2227.0  ...
# 2  Hospitalizations for asthma           NaN        Number      708.0  ...
# 3  Hospitalizations for asthma           NaN        Number     3520.0  ...
# 4  Hospitalizations for asthma           NaN        Number      123.0  ...
#
#    StratificationCategory1 Stratification1 Stratification2  \
# 0                   Gender            Male             NaN
# 1                  Overall         Overall             NaN
# 2                  Overall         Overall             NaN
# 3                   Gender          Female             NaN
# 4           Race/Ethnicity        Hispanic             NaN
#
#                                       GeoLocation  LocationID TopicID  \
# 0    POINT (-92.27449074299966 34.74865012400045)           5     AST
# 1  POINT (-106.13361092099967 38.843840757000464)           8     AST
# 2                    POINT (-77.036871 38.907192)          11     AST
# 3    POINT (-83.62758034599966 32.83968109300048)          13     AST
# 4     POINT (-84.71439026999968 44.6613195430005)          26     AST
#
#   QuestionID  DataValueTypeID StratificationCategoryID1  StratificationID1
# 0     AST3_1             NMBR                    GENDER               GENM
# 1     AST3_1             NMBR                   OVERALL                OVR
# 2     AST3_1             NMBR                   OVERALL                OVR
# 3     AST3_1             NMBR                    GENDER               GENF
# 4     AST3_1             NMBR                      RACE                HIS
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Quick analysis of Questions
#
# I noticed the structure of the data varies a little between each question
# so I might either need to:
#
#     1) Implement a cleaning process to standardize
#     2) Tackle each question individually

# %%
# First what are the questions?
questions = list(data['Question'].unique())
questions
# Out:
# ['Hospitalizations for asthma',
#  'Asthma mortality rate',
#  'Emergency department visit rate for asthma',
#  'Asthma prevalence among women aged 18-44 years',
#  'Current asthma prevalence among adults aged >= 18 years',
#  'Influenza vaccination among noninstitutionalized adults aged >= 65 years with asthma',
#  'Influenza vaccination among noninstitutionalized adults aged 18-64 years with asthma',
#  'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with asthma',
#  'Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with asthma']

# %%
# Understanding "Hospitalizations for asthma" looking at Overall for now for simplicity
hosp_overall = data[
    (data["Question"] == "Hospitalizations for asthma")
    & (data["StratificationCategory1"] == "Overall")
]
hosp_overall.head()
# Out:
#     YearStart  YearEnd LocationAbbr          LocationDesc DataSource   Topic  \
# 1        2018     2018           CO              Colorado  SEDD; SID  Asthma
# 2        2018     2018           DC  District of Columbia  SEDD; SID  Asthma
# 7        2013     2013           PR           Puerto Rico  SEDD; SID  Asthma
# 8        2017     2017           PR           Puerto Rico  SEDD; SID  Asthma
# 44       2013     2013           GU                  Guam  SEDD; SID  Asthma
#
#                        Question     DataValueUnit DataValueType  DataValue  \
# 1   Hospitalizations for asthma               NaN        Number     2227.0
# 2   Hospitalizations for asthma               NaN        Number      708.0
# 7   Hospitalizations for asthma               NaN        Number        NaN
# 8   Hospitalizations for asthma               NaN        Number        NaN
# 44  Hospitalizations for asthma  cases per 10,000    Crude Rate        NaN
#
#     ...  StratificationCategory1 Stratification1 Stratification2  \
# 1   ...                  Overall         Overall             NaN
# 2   ...                  Overall         Overall             NaN
# 7   ...                  Overall         Overall             NaN
# 8   ...                  Overall         Overall             NaN
# 44  ...                  Overall         Overall             NaN
#
#                                        GeoLocation  LocationID TopicID  \
# 1   POINT (-106.13361092099967 38.843840757000464)           8     AST
# 2                     POINT (-77.036871 38.907192)          11     AST
# 7                     POINT (-66.590149 18.220833)          72     AST
# 8                     POINT (-66.590149 18.220833)          72     AST
# 44                    POINT (144.793731 13.444304)          66     AST
#
#    QuestionID  DataValueTypeID StratificationCategoryID1  StratificationID1
# 1      AST3_1             NMBR                   OVERALL                OVR
# 2      AST3_1             NMBR                   OVERALL                OVR
# 7      AST3_1             NMBR                   OVERALL                OVR
# 8      AST3_1             NMBR                   OVERALL                OVR
# 44     AST3_1          CRDRATE                   OVERALL                OVR
#
# [5 rows x 25 columns]

# %%
# Create adictionary that generates the pairings of DataValueType and DataValueUnit
hosp_overall_pairing = {
    data_type: list(data[data["DataValueType"] == data_type]["DataValueUnit"].unique())
    for data_type in data["DataValueType"].unique()
}
hosp_overall_pairing
# Out:
# {'Number': [nan, 'Number'],
#  'Crude Rate': ['cases per 10,000', 'cases per 1,000,000'],
#  'Age-adjusted Rate': ['cases per 10,000', 'cases per 1,000,000'],
#  'Crude Prevalence': ['%'],
#  'Age-adjusted Prevalence': ['%']}

# %%
# I think it would be interesting to perform this
# pairing but with the Stratification1 and StratificationCategory1 columns

strat_pairings = {
    strat_category: list(data[data["StratificationCategory1"] == strat_category]['Stratification1'].unique())
    for strat_category in data["StratificationCategory1"].unique()
}
strat_pairings
# Out:
# {'Gender': ['Male', 'Female'],
#  'Overall': ['Overall'],
#  'Race/Ethnicity': ['Hispanic',
#   'White, non-Hispanic',
#   'Asian or Pacific Islander',
#   'American Indian or Alaska Native',
#   'Black, non-Hispanic',
#   'Other, non-Hispanic',
#   'Multiracial, non-Hispanic']}

# %% [markdown]
# ### Now can we abstract these pairings into each question?

# %%
question_dict = {}              # Key:Value => Question:DataFrame
question_pairings = {}          # Key:Value => Question:Pairing Dictionary

for question in data["Question"].unique():
    question_dict[question] = data[data["Question"] == question]
    question_pairings[question] = {
        data_type: list(data[data["DataValueType"] == data_type]["DataValueUnit"].unique())
        for data_type in data["DataValueType"].unique()
    }

# %%
question_dict[questions[-1]].head()
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc DataSource   Topic  \
# 28938       2020     2020           AK       Alaska      BRFSS  Asthma
# 28944       2015     2015           AK       Alaska      BRFSS  Asthma
# 28945       2021     2021           AL      Alabama      BRFSS  Asthma
# 28949       2014     2014           AK       Alaska      BRFSS  Asthma
# 28951       2012     2012           AK       Alaska      BRFSS  Asthma
#
#                                                 Question DataValueUnit  \
# 28938  Pneumococcal vaccination among noninstitutiona...             %
# 28944  Pneumococcal vaccination among noninstitutiona...             %
# 28945  Pneumococcal vaccination among noninstitutiona...             %
# 28949  Pneumococcal vaccination among noninstitutiona...             %
# 28951  Pneumococcal vaccination among noninstitutiona...             %
#
#                  DataValueType  DataValue  ...  StratificationCategory1  \
# 28938  Age-adjusted Prevalence       68.3  ...                  Overall
# 28944         Crude Prevalence        NaN  ...           Race/Ethnicity
# 28945         Crude Prevalence        NaN  ...           Race/Ethnicity
# 28949  Age-adjusted Prevalence        NaN  ...           Race/Ethnicity
# 28951  Age-adjusted Prevalence        NaN  ...           Race/Ethnicity
#
#                  Stratification1 Stratification2  \
# 28938                    Overall             NaN
# 28944  Multiracial, non-Hispanic             NaN
# 28945        Other, non-Hispanic             NaN
# 28949        Other, non-Hispanic             NaN
# 28951        Other, non-Hispanic             NaN
#
#                                          GeoLocation  LocationID TopicID  \
# 28938  POINT (-147.72205903599973 64.84507995700051)           2     AST
# 28944  POINT (-147.72205903599973 64.84507995700051)           2     AST
# 28945   POINT (-86.63186076199969 32.84057112200048)           1     AST
# 28949  POINT (-147.72205903599973 64.84507995700051)           2     AST
# 28951  POINT (-147.72205903599973 64.84507995700051)           2     AST
#
#       QuestionID  DataValueTypeID StratificationCategoryID1  StratificationID1
# 28938     AST6_2       AGEADJPREV                   OVERALL                OVR
# 28944     AST6_2          CRDPREV                      RACE                MRC
# 28945     AST6_2          CRDPREV                      RACE                OTH
# 28949     AST6_2       AGEADJPREV                      RACE                OTH
# 28951     AST6_2       AGEADJPREV                      RACE                OTH
#
# [5 rows x 25 columns]

# %%
# Print out the question and the question_pairing dictionary corresponding to the said question
for question in questions:
    print(f"Question: {question}")
    print(question_pairings[question])
    print()
# Out:
# Question: Hospitalizations for asthma
# {'Number': [nan, 'Number'], 'Crude Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Age-adjusted Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Crude Prevalence': ['%'], 'Age-adjusted Prevalence': ['%']}
#
# Question: Asthma mortality rate
# {'Number': [nan, 'Number'], 'Crude Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Age-adjusted Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Crude Prevalence': ['%'], 'Age-adjusted Prevalence': ['%']}
#
# Question: Emergency department visit rate for asthma
# {'Number': [nan, 'Number'], 'Crude Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Age-adjusted Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Crude Prevalence': ['%'], 'Age-adjusted Prevalence': ['%']}
#
# Question: Asthma prevalence among women aged 18-44 years
# {'Number': [nan, 'Number'], 'Crude Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Age-adjusted Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Crude Prevalence': ['%'], 'Age-adjusted Prevalence': ['%']}
#
# Question: Current asthma prevalence among adults aged >= 18 years
# {'Number': [nan, 'Number'], 'Crude Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Age-adjusted Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Crude Prevalence': ['%'], 'Age-adjusted Prevalence': ['%']}
#
# Question: Influenza vaccination among noninstitutionalized adults aged >= 65 years with asthma
# {'Number': [nan, 'Number'], 'Crude Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Age-adjusted Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Crude Prevalence': ['%'], 'Age-adjusted Prevalence': ['%']}
#
# Question: Influenza vaccination among noninstitutionalized adults aged 18-64 years with asthma
# {'Number': [nan, 'Number'], 'Crude Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Age-adjusted Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Crude Prevalence': ['%'], 'Age-adjusted Prevalence': ['%']}
#
# Question: Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with asthma
# {'Number': [nan, 'Number'], 'Crude Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Age-adjusted Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Crude Prevalence': ['%'], 'Age-adjusted Prevalence': ['%']}
#
# Question: Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with asthma
# {'Number': [nan, 'Number'], 'Crude Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Age-adjusted Rate': ['cases per 10,000', 'cases per 1,000,000'], 'Crude Prevalence': ['%'], 'Age-adjusted Prevalence': ['%']}
